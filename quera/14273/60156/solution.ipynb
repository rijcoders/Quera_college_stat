# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# <div id="h1" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# <div align=center>
# 		</div>
# 		<hr/>
# 		<font color=#0f6d02 size=7>
# 			<br />
# 			<div align=center>
# درآمد خانواده
# </div>
# 		</font>
#         <br />

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         </font>
#         <hr>
# داده‌ی درآمد خانوارهای نمونه شهری را برحسب ۱۰ بازه‌ی درآمدی که توسط مرکز آمار ایران منتشر شده در familydata.csv در اختیار داریم.
#         <br>
#         ابتدا داده را با کتابخانه pandas می‌خوانیم و نگاهی به آن می‌اندازیم :
#     </font>
# </div>

# %%
import pandas as pd 

family_data = pd.read_csv("familydata.csv")
family_data
# Out:
#             Provide  code  Population  7.5  7.5-10  10-12  12-16-05  \
# 0              Iran    99       20350  731     567    570      1548
# 1    East Azerbijan     3         602   12       7     11        38
# 2   West Azerbaijan     4         527   55      18     23        63
# 3           Ardabil    24         504   24       9     19        43
# 4           Isfahan    10         685   13      18     11        34
# 5            Alborz    30         424    1       4      4         3
# 6              Ilam    16         478   10      15      8        46
# 7           Bushehr    18         581    9      14     17        44
# 8            Tehran    23        1527    3       8      5        31
# 9         Charmahal    14         677   24      16      7        39
# 10   South khorasan    29         650   41      28     30        66
# 11  Razavi khorasan     9         765   24      23     25        80
# 12   North khorasan    28         712   28      24     25        91
# 13         Kuzestan     6         663    7       4      9        41
# 14           Zanjan    19         609   29      13     23        50
# 15           Semnan    20         480    9       8      7        39
# 16           Sistan    11         808  175      84     75        88
# 17             Fars     7         693    7      16     12        50
# 18           Qazvin    26         420    3       4      7        21
# 19              Qom    25         539    3       5      5        39
# 20        Kurdistan    12         505   10       7     11        44
# 21           Kerman     8         516   34      23     32        74
# 22       Kermanshah     5         665   14      19     17        53
# 23       Kohkiloyeh    17         539    9      10      6        24
# 24         Golestan    27        1073   37      49     50       103
# 25           Gillan     1         900   23      23     22        53
# 26         Lorestan    15         473   18      17     13        51
# 27       Mazandaran     2         471    2       3      7        13
# 28          Markazi     0         590   21      25     15        43
# 29        Hormozgan    22         895   27      26     34        72
# 30          Hamedan    13         774   39      33     25        85
# 31             Yazd    21         605   20      14     15        27
#
#     16.5-19.5  19.5-27  27-36  36-48  48-60    60
# 0        1375     3813   3894   3371   1847  2634
# 1          31      140    127    107     54    75
# 2          44      131     85     63     24    21
# 3          36      109     93     78     41    52
# 4          40      120    151    127     64   107
# 5           7       45     88    112     61    99
# 6          39      103     91     82     42    42
# 7          30       91    102    118     65    91
# 8          38      163    256    266    217   540
# 9          48      128    124    131     84    76
# 10         41      150    118     91     34    51
# 11         59      172    121    110     65    86
# 12         59      150    110     97     45    83
# 13         44      146    134    135     66    77
# 14         46      108    128     93     47    72
# 15         34      150    125     57     21    30
# 16         54      102     87     55     44    44
# 17         51      129    133    130     70    95
# 18         18      102    111     79     39    36
# 19         43      117    126    100     48    53
# 20         56      141    102     59     42    33
# 21         48       91     97     51     31    35
# 22         58      146    141    122     47    48
# 23         29       91    116    103     67    84
# 24        103      174    185    165     87   120
# 25         46      143    198    165    102   125
# 26         40       85     81     84     32    52
# 27         20       64    110    101     61    90
# 28         40      112    127    108     60    39
# 29         71      126    147    164     89   139
# 30         65      169    151    116     39    52
# 31         37      115    129    102     59    87

# %% [markdown]
# <br>
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#        <li>
#            اگر خانوارهای با درآمد زیر ۱۰ میلیون در سال فقیر حساب شوند (صرفاً در این تمرین این معیار را اختراع کرده‌ایم.) آنگاه احتمال اینکه خانواده‌ای از بین کل خانوارها انتخاب کنیم و فقیر باشد چقدر است؟ (Y متغیر تصادفی فقیر بودن یا نبودن است. Y=1 یعنی فقیر)
#         </li>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#95026b size=5>
#                   پاسخ:
#         </font>
# 	</font>
# </div>

# %%
family_data.iloc[2,:]
P_Y = sum(family_data.iloc[0,:]['7.5':'7.5-10'])/family_data.iloc[0,:]['Population']
P_Y
# Out:
# 0.06378378378378378

# %% [markdown]
# <br>
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#        <li>
# حال این احتمال را برای تک تک استان‌ها حساب کنید.
#            <br>
#             برای این کار ستونی جدید با عنوان poor  که نشان‌دهنده‌ی تعداد خانوارهای فقیر هر استان است و ستونی با عنوان poor probability که نشان‌دهنده‌ی درصد خانوار فقیر به کلّ خانواده‌های هر استان است را اضافه می‌کنیم. به عبارت دیگر این ستون احتمال فقیر بودن به شرط سکونت (ضرب‌در ۱۰۰) در هر استان است.
#         </li>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#95026b size=5>
#                   پاسخ:
#         </font>
# 	</font>
# </div>

# %%
family_data['poor'] = (family_data['7.5']+family_data['7.5-10'])
family_data['poor probability'] = ((family_data['poor'])/family_data['Population'])*100
family_data
# Out:
#             Provide  code  Population  7.5  7.5-10  10-12  12-16-05  \
# 0              Iran    99       20350  731     567    570      1548
# 1    East Azerbijan     3         602   12       7     11        38
# 2   West Azerbaijan     4         527   55      18     23        63
# 3           Ardabil    24         504   24       9     19        43
# 4           Isfahan    10         685   13      18     11        34
# 5            Alborz    30         424    1       4      4         3
# 6              Ilam    16         478   10      15      8        46
# 7           Bushehr    18         581    9      14     17        44
# 8            Tehran    23        1527    3       8      5        31
# 9         Charmahal    14         677   24      16      7        39
# 10   South khorasan    29         650   41      28     30        66
# 11  Razavi khorasan     9         765   24      23     25        80
# 12   North khorasan    28         712   28      24     25        91
# 13         Kuzestan     6         663    7       4      9        41
# 14           Zanjan    19         609   29      13     23        50
# 15           Semnan    20         480    9       8      7        39
# 16           Sistan    11         808  175      84     75        88
# 17             Fars     7         693    7      16     12        50
# 18           Qazvin    26         420    3       4      7        21
# 19              Qom    25         539    3       5      5        39
# 20        Kurdistan    12         505   10       7     11        44
# 21           Kerman     8         516   34      23     32        74
# 22       Kermanshah     5         665   14      19     17        53
# 23       Kohkiloyeh    17         539    9      10      6        24
# 24         Golestan    27        1073   37      49     50       103
# 25           Gillan     1         900   23      23     22        53
# 26         Lorestan    15         473   18      17     13        51
# 27       Mazandaran     2         471    2       3      7        13
# 28          Markazi     0         590   21      25     15        43
# 29        Hormozgan    22         895   27      26     34        72
# 30          Hamedan    13         774   39      33     25        85
# 31             Yazd    21         605   20      14     15        27
#
#     16.5-19.5  19.5-27  27-36  36-48  48-60    60  poor  poor probability
# 0        1375     3813   3894   3371   1847  2634  1298          6.378378
# 1          31      140    127    107     54    75    19          3.156146
# 2          44      131     85     63     24    21    73         13.851992
# 3          36      109     93     78     41    52    33          6.547619
# 4          40      120    151    127     64   107    31          4.525547
# 5           7       45     88    112     61    99     5          1.179245
# 6          39      103     91     82     42    42    25          5.230126
# 7          30       91    102    118     65    91    23          3.958692
# 8          38      163    256    266    217   540    11          0.720367
# 9          48      128    124    131     84    76    40          5.908419
# 10         41      150    118     91     34    51    69         10.615385
# 11         59      172    121    110     65    86    47          6.143791
# 12         59      150    110     97     45    83    52          7.303371
# 13         44      146    134    135     66    77    11          1.659125
# 14         46      108    128     93     47    72    42          6.896552
# 15         34      150    125     57     21    30    17          3.541667
# 16         54      102     87     55     44    44   259         32.054455
# 17         51      129    133    130     70    95    23          3.318903
# 18         18      102    111     79     39    36     7          1.666667
# 19         43      117    126    100     48    53     8          1.484230
# 20         56      141    102     59     42    33    17          3.366337
# 21         48       91     97     51     31    35    57         11.046512
# 22         58      146    141    122     47    48    33          4.962406
# 23         29       91    116    103     67    84    19          3.525046
# 24        103      174    185    165     87   120    86          8.014911
# 25         46      143    198    165    102   125    46          5.111111
# 26         40       85     81     84     32    52    35          7.399577
# 27         20       64    110    101     61    90     5          1.061571
# 28         40      112    127    108     60    39    46          7.796610
# 29         71      126    147    164     89   139    53          5.921788
# 30         65      169    151    116     39    52    72          9.302326
# 31         37      115    129    102     59    87    34          5.619835

# %% [markdown]
# <br>
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#        <li>
# به نظر شما آیا احتمال فقیر بودن و ساکن چه استانی بودن مستقل از هم هستند؟
#         </li>
#         <li>
#             احتمال پیشامد توأم فقیر بودن و ساکن استان تهران بودن را بدست آورید. (P_tehranY)
#         </li>
#         <li>
# احتمال ساکن استان تهران بودن یعنی
#             $P(X=tehran)$
#              را بدست آورید. (P_tehran)
# </li>
# <li>
# احتمال فقیر بودن
#     $P(Y=1)$ را بالاتر بدست آوردیم و در
#    P_Y ریختیم. آیا احتمال توأم برابر حاصل ضرب احتمال ساکن تهران بودن و احتمال فقیر بودن می‌شود؟
# </li>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#95026b size=5>
#                   پاسخ:
#         </font>
# 	</font>
# </div>

# %%
P_tehranY = family_data['poor'][8] / family_data['Population'][0]
P_tehran =  family_data['Population'][8] / family_data['Population'][0]
P_tehranY
# Out:
# 0.0005405405405405405

# %%
P_tehran*P_Y
# Out:
# 0.004786134537485888

# %% [markdown]
# <br>
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#        <li>
# با استفاده از توزیع شرطی احتمال پیشامد آنکه اگر بدانیم فردی فقیر است و ساکن استان سیستان یا کرمان باشد چقدر است؟ (P_kermansistan)
# </li>
#         <li>
#             حال اگر بدانیم فردی فقیر است احتمال سکونت در استان های قزوین یا زنجان یا سمنان چقدر است؟ (P_Qazvinzanjansemnan)
#         </li>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#95026b size=5>
#                   پاسخ:
#         </font>
# 	</font>
# </div>

# %%
P_kermansistan = ((sum(family_data[family_data['Provide']=='Kerman']['poor'])+sum(family_data[family_data['Provide']=='Sistan']['poor']))/family_data['Population'][0])/P_Y
P_kermansistan
# Out:
# 0.24345146379044685

# %%
P_Qazvinzanjansemnan = (family_data["poor"][18] + family_data["poor"][14] +family_data["poor"][15]) / family_data['Population'][0]/P_Y
P_Qazvinzanjansemnan
# Out:
# 0.05084745762711864

# %% [markdown]
# <br>
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#        <li>
#         اگر بدانیم فردی در استان یزد زندگی می‌کند احتمال فقیر بودن آن تغییری مي‌کند؟ اگر خانوارهای با درآمد سالاته بالای ۴۸ میلیون
#         را ثروتمند بدانیم چه طور؟ (یعنی دانستن اینکه خانواده ساکن یزد است احتمال را تغییر می‌دهد؟)
#         <br>
#         همین مسئله را در بوشهر بررسی کنید. پس به طورکلی احتمالات زیر را بدست آورید:
#         </li>
#         <li>
#             اگر بدانیم خانواده ای ساکن یزد است احتمال فقیر بودن آن ($P(poor|X=yazd)$) چقدر است؟ (yazd_poor)
#         </li>
#         <li>
#             احتمال ثروت‌مند بودن آن خانواده($P(rich|X=yazd)$) چه‌طور؟ (yazd_rich)
#         </li>
#         <li>
#             اگر بدانیم خانواده‌ای ساکن بوشهر است احتمال فقیر بودن آن ($P(poor|X=bushehr)$)  چقدر است؟ (bushehr_poor)
#         </li>
#         <li>
#             اگر بدانیم خانواده‌ای ساکن بوشهر است احتمال ثروت‌مند بودن آن ($P(rich|X=bushehr)$) چقدر است؟ (bushehr_rich)
#         </li>
#         <li>
#             چه تفاوتی در این چهار مقدار مشاهده می‌کنید؟
#             </li>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#95026b size=5>
#                   پاسخ:
#         </font>
# 	</font>
# </div>

# %%
family_data['rich'] = (family_data['48-60']+family_data['60'])
yazd_poor = family_data["poor"][31] / family_data["Population"][31]
yazd_rich = family_data["rich"][31] / family_data["Population"][31]
bushehr_poor = family_data["poor"][7] / family_data["Population"][7] 
bushehr_rich = 1 - bushehr_poor
print(yazd_poor)
print(yazd_rich)
print(bushehr_poor)
print(bushehr_rich)
# Out:
# 0.05619834710743802
# 0.2413223140495868
# 0.039586919104991396
# 0.9604130808950087
